# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score

from IPython.display import Image
import graphviz
import pydotplus 

from sklearn.preprocessing import LabelEncoder

pd.options.display.max_columns = 25

# %% [markdown]
# # Iris dataset

# %%
df_iris = pd.read_csv("iris.csv")
df_iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
target = "Species"
features = [i for i in df_iris if i not in ['Id', 'Species']]

X_train, X_test, y_train, y_test = train_test_split(
    df_iris[features],
    df_iris[target],
    random_state=42
) 
tree_class = tree.DecisionTreeClassifier(random_state=0)
tree_class.fit(X_train, y_train)
print("Правильность на обучающем наборе: {:.3f}".format(tree_class.score(X_train, y_train)))
print("Правильность на тестовом наборе: {:.3f}".format(tree_class.score(X_test, y_test)))
# Out:
# Правильность на обучающем наборе: 1.000
# Правильность на тестовом наборе: 1.000

# %%
dot_data = tree.export_graphviz(decision_tree=tree_class, out_file="tree.out",
                                max_depth=7,
                                feature_names=features,
                                class_names=df_iris[target].unique(),
                                filled=True, rounded=True,  
                                special_characters=True,
                                proportion = True, precision=2,
                                label='all', impurity=False,
)  

graph = pydotplus.graphviz.graph_from_dot_file("tree.out")
Image(graph.create_png())

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_iris[features],
    df_iris[target],
    random_state=42
) 
tree_class = tree.DecisionTreeClassifier(random_state=42, max_depth=3)
tree_class.fit(X_train, y_train)
print("Правильность на обучающем наборе: {:.3f}".format(tree_class.score(X_train, y_train)))
print("Правильность на тестовом наборе: {:.3f}".format(tree_class.score(X_test, y_test)))
# Out:
# Правильность на обучающем наборе: 0.955
# Правильность на тестовом наборе: 1.000

# %%
dot_data = tree.export_graphviz(decision_tree=tree_class, out_file="tree.out",
                                max_depth=7,
                                feature_names=features,
                                class_names=df_iris[target].unique(),
                                filled=True, rounded=True,  
                                special_characters=True,
                                proportion = True, precision=2,
                                label='all', impurity=False,
)  

graph = pydotplus.graphviz.graph_from_dot_file("tree.out")
Image(graph.create_png())

# %%
cross = cross_val_score(tree_class, df_iris[features], df_iris['Species'], cv=5)
print(cross)
print(np.mean(cross))
# Out:
# [0.96666667 0.96666667 0.93333333 1.         1.        ]
# 0.9733333333333334
